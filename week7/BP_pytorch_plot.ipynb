# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import seaborn as sns

import matplotlib.pyplot as plt
from torchsummary import summary
import numpy as np

# %%
# 데이터셋 인스턴스 생성

data = pd.read_csv("C:\\Users\\yale3\\Downloads\\BP_data.csv")  # CSV 파일 경로

# %%
data
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %%
data.columns
# Out:
# Index(['Patient_Number', 'Blood_Pressure_Abnormality', 'Level_of_Hemoglobin',
#        'Genetic_Pedigree_Coefficient', 'Age', 'BMI', 'Sex', 'Pregnancy',
#        'Smoking', 'Physical_activity', 'salt_content_in_the_diet',
#        'alcohol_consumption_per_day', 'Level_of_Stress',
#        'Chronic_kidney_disease', 'Adrenal_and_thyroid_disorders'],
#       dtype='object')

# %%
# 결측치 확인
data.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %%
data.drop(columns=["Pregnancy"], inplace=True)

# 2. 'Genetic_Pedigree_Coefficient', 'alcohol_consumption_per_day'의 결측치를 각 컬럼 평균으로 채움
for col in ["Genetic_Pedigree_Coefficient", "alcohol_consumption_per_day"]:
    data[col] = data[col].fillna(data[col].mean())

# %%
data.isnull().sum()
# Out:
# Patient_Number                   0
# Blood_Pressure_Abnormality       0
# Level_of_Hemoglobin              0
# Genetic_Pedigree_Coefficient     0
# Age                              0
# BMI                              0
# Sex                              0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# alcohol_consumption_per_day      0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# dtype: int64

# %%
plt.figure(figsize=(5, 4))
sns.countplot(x="Blood_Pressure_Abnormality", data=data)
plt.title("Count of Blood Pressure Abnormality (0/1)")
plt.xlabel("Abnormality")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x="Sex", hue="Smoking", data=data)
plt.title("Smoking Status by Sex")
plt.xlabel("Sex (0: Female, 1: Male)")
plt.ylabel("Count")
plt.legend(title="Smoking (0: Non-smoker, 1: Smoker)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x="Sex", hue="Genetic_Pedigree_Coefficient", data=data)
plt.title("sex - genetic")
plt.xlabel("Sex (0: Female, 1: Male)")
plt.ylabel("Count")
plt.legend(title="")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x=data["Physical_activity"])
plt.title("Boxplot of Physical Activity")
plt.xlabel("Physical Activity Level")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(x="Blood_Pressure_Abnormality", y="Physical_activity", data=data)
plt.title("Physical Activity by Blood Pressure Abnormality")
plt.xlabel("Blood Pressure Abnormality (0: Normal, 1: Abnormal)")
plt.ylabel("Physical Activity Level")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.violinplot(x=data["Physical_activity"])
plt.title("Violin Plot of Physical Activity")
plt.xlabel("Physical Activity Level")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = data.corr()

sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.hist(data["Age"], bins=20, color="lightgreen", edgecolor="black")
plt.title("Histogram of Age")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
    
plt.figure(figsize=(8, 5))

# BMI 선 그래프 (왼쪽 Y축)
sns.lineplot(x="Age", y="BMI", data=data, label="BMI", color="blue")

# BP 선 그래프 (오른쪽 Y축)
ax1 = plt.gca()  # 현재 축 가져오기
ax2 = ax1.twinx()  # 오른쪽 Y축 생성

sns.lineplot(x="Age", y="Blood_Pressure_Abnormality", data=data, label="BP Abnormality", color="red", ax=ax2)

# 설정
ax1.set_xlabel("Age")
ax1.set_ylabel("BMI", color="blue")
ax2.set_ylabel("BP Abnormality Rate", color="red")
plt.title("Age vs BMI and Blood Pressure Abnormality")
ax1.grid(True)

plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(data["Age"], data["Physical_activity"], alpha=0.3, color="crimson")
plt.title("Age vs Physical_activity")
plt.xlabel("Age")
plt.ylabel("Physical_activity (0 = Normal, 1 = Abnormal)")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.scatter(data["Age"], data["salt_content_in_the_diet"], alpha=0.3, color="crimson")
plt.title("Age vs salt_content_in_the_diet")
plt.xlabel("Age")
plt.ylabel("salt_content_in_the_diet (0 = Normal, 1 = Abnormal)")
plt.grid(True)
plt.show()

# %%
# 데이터와 타겟 분리
X = data.drop('Blood_Pressure_Abnormality', axis=1).values
y = data['Blood_Pressure_Abnormality'].values

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape,
# Out:
# ((1600, 13), (400, 13), (1600,), (400,))

# %%
# Convert to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.int64)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.int64)

# %%
# Create DataLoader
train_dataset = TensorDataset(X_train, y_train)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

test_dataset = TensorDataset(X_test, y_test)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([1600, 13]),
#  torch.Size([400, 13]),
#  torch.Size([1600]),
#  torch.Size([400]))

# %% [markdown]
# # 모델 정의

# %%
class BPClassifier(nn.Module):
    def __init__(self):
        super(BPClassifier, self).__init__()
        self.fc1 = nn.Linear(13, 64)
        self.fc2 = nn.Linear(64, 32)
        self.output = nn.Linear(32, 2)  # 2개의 클래스 (0, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.output(x)  # CrossEntropyLoss 쓸 거면 softmax는 생략
        return x
# Initialize the model, loss function, and optimizer
model = BPClassifier()

# %% [markdown]
# # 손실 함수 및 최적화 기법 정의

# %%
criterion = nn.CrossEntropyLoss()  # 이진 분류라도 CrossEntropyLoss 사용 (출력 2개로)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # 모델 학습

# %%
# Variables to store loss and accuracy
train_losses = []
test_accuracies = []

# Training loop
num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for inputs, labels in train_dataloader:
        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    # Calculate average loss over an epoch
    train_losses.append(running_loss / len(train_dataloader))

    # Evaluate on test data
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_accuracies.append(accuracy)

    print(f"Epoch {epoch + 1}/{num_epochs}, Loss: {train_losses[-1]:.4f}, Accuracy: {accuracy:.2f}%")

print("Training complete.")
# Out:
# Epoch 1/100, Loss: 0.6626, Accuracy: 72.25%
# Epoch 2/100, Loss: 0.5585, Accuracy: 72.50%
# Epoch 3/100, Loss: 0.5102, Accuracy: 74.50%
# Epoch 4/100, Loss: 0.4771, Accuracy: 77.00%
# Epoch 5/100, Loss: 0.4412, Accuracy: 81.75%
# Epoch 6/100, Loss: 0.4048, Accuracy: 82.25%
# Epoch 7/100, Loss: 0.3686, Accuracy: 85.00%
# Epoch 8/100, Loss: 0.3406, Accuracy: 85.75%
# Epoch 9/100, Loss: 0.3198, Accuracy: 87.00%
# Epoch 10/100, Loss: 0.3076, Accuracy: 87.50%
# Epoch 11/100, Loss: 0.2949, Accuracy: 87.50%
# Epoch 12/100, Loss: 0.2841, Accuracy: 87.00%
# Epoch 13/100, Loss: 0.2772, Accuracy: 88.25%
# Epoch 14/100, Loss: 0.2721, Accuracy: 87.75%
# Epoch 15/100, Loss: 0.2651, Accuracy: 88.00%
# Epoch 16/100, Loss: 0.2598, Accuracy: 88.00%
# Epoch 17/100, Loss: 0.2533, Accuracy: 89.00%
# Epoch 18/100, Loss: 0.2544, Accuracy: 88.75%
# Epoch 19/100, Loss: 0.2481, Accuracy: 88.00%
# Epoch 20/100, Loss: 0.2442, Accuracy: 87.50%
# Epoch 21/100, Loss: 0.2373, Accuracy: 88.75%
# ...

# %% [markdown]
# # 모델 평가

# %%
# Evaluation
model.eval()
all_labels = []
all_predictions = []
with torch.no_grad():
    for inputs, labels in test_dataloader:
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        all_labels.extend(labels.cpu().numpy())
        all_predictions.extend(predicted.cpu().numpy())

# Convert to numpy arrays
all_labels = np.array(all_labels)
all_predictions = np.array(all_predictions)

# Calculate metrics
conf_matrix = confusion_matrix(all_labels, all_predictions)
f1 = f1_score(all_labels, all_predictions, average='weighted')
precision = precision_score(all_labels, all_predictions, average='weighted')
recall = recall_score(all_labels, all_predictions, average='weighted')

# Calculate specificity for each class
specificity = []
for i in range(conf_matrix.shape[0]):
    tn = conf_matrix.sum() - (conf_matrix[i, :].sum() + conf_matrix[:, i].sum() - conf_matrix[i, i])
    fp = conf_matrix[:, i].sum() - conf_matrix[i, i]
    specificity.append(tn / (tn + fp))

print(f'Confusion Matrix:\n{conf_matrix}')
print(f'F1 Score: {f1:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'Specificity: {np.mean(specificity):.2f}')
# Out:
# Confusion Matrix:
# [[183  25]
#  [ 33 159]]
# F1 Score: 0.85
# Precision: 0.86
# Recall: 0.85
# Specificity: 0.85

# %%
# Plot the loss and accuracy
plt.figure(figsize=(12, 5))

# Plot loss
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()

# Plot accuracy
plt.subplot(1, 2, 2)
plt.plot(test_accuracies, label='Test Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Test Accuracy Over Epochs')
plt.legend()

plt.show()
